# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('bank.csv')

df.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no   2343.0     yes   no  unknown
# 1   56      admin.  married  secondary      no     45.0      no   no  unknown
# 2   41  technician  married  secondary      no   1270.0     yes   no  unknown
# 3   55    services  married  secondary      no   2476.0     yes   no  unknown
# 4   54      admin.  married   tertiary      no    184.0      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome    y
# 0  5.0   may    1042.0         1   -1.0         0  unknown  yes
# 1  5.0   may    1467.0         1   -1.0         0  unknown  yes
# 2  5.0   may    1389.0         1   -1.0         0  unknown  yes
# 3  5.0   may     579.0         1   -1.0         0  unknown  yes
# 4  5.0   may     673.0         2   -1.0         0  unknown  yes

# %%
import pandas as pd
df=pd.read_csv('bank.csv')

age_mean = data['age'].mean()
age_median = data['age'].median()
age_std = data['age'].std()



hours_mean = data['hours-per-week'].mean()
hours_median = data['hours-per-week'].median()
hours_std = data['hours-per-week'].std()


print(f"Age - Mean: {age_mean}, Median: {age_median}, Standard Deviation: {age_std}")
print(f"Hours per Week - Mean: {hours_mean}, Median: {hours_median}, Standard Deviation: {hours_std}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 import pandas as pd
#       2 df=pd.read_csv('bank.csv')
# ----> 4 age_mean = data['age'].mean()
#       5 age_median = data['age'].median()
#       6 age_std = data['age'].std()
#
# NameError: name 'data' is not defined

# %%
df.head()

# %%
workclass_counts = df['workclass'].value_counts()


print("Distribution of individuals across workclass categories:")
print(workclass_counts)
print("\nMost common workclass category:", workclass_counts.idxmax())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'workclass'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 workclass_counts = df['workclass'].value_counts()
# ...

# %%
education_counts = df['education'].value_counts()


most_common_education = education_counts.idxmax()


education_salary_crosstab = pd.crosstab(df['education'], df['salary'], normalize='index') * 100


print("Frequency distribution of education levels:")
print(education_counts)
print("\nMost common education level:", most_common_education)
print("\nCorrelation of education level with salary:")
print(education_salary_crosstab)
# Out:
# Frequency distribution of education levels:
# education
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: count, dtype: int64
#
# Most common education level: HS-grad
#
# Correlation of education level with salary:
# salary             <=50K       >50K
# education
# 10th           93.354770   6.645230
# 11th           94.893617   5.106383
# 12th           92.378753   7.621247
# 1st-4th        96.428571   3.571429
# 5th-6th        95.195195   4.804805
# 7th-8th        93.808050   6.191950
# 9th            94.747082   5.252918
# Assoc-acdm     75.164011  24.835989
# Assoc-voc      73.878437  26.121563
# Bachelors      58.524743  41.475257
# ...

# %%
unique_countries = df['native-country'].nunique()


country_counts = df['native-country'].value_counts()


most_represented_country = country_counts.idxmax()
most_represented_count = country_counts.max()


print("Number of unique native-country values:", unique_countries)
print("\nCountry with the most individuals represented:", most_represented_country)
print("Number of individuals from this country:", most_represented_count)
# Out:
# Number of unique native-country values: 42
#
# Country with the most individuals represented: United-States
# Number of individuals from this country: 29170

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


df = pd.read_excel('dataset1.xlsx')


plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")

sns.scatterplot(data=df, x='capital-gain', y='capital-loss', hue='salary', palette={'<=50K': 'blue', '>50K': 'orange'}, alpha=0.7)


plt.title("Capital Gain vs. Capital Loss by Salary")
plt.xlabel("Capital Gain")
plt.ylabel("Capital Loss")
plt.legend(title="Salary")


plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df = pd.read_excel('dataset1.xlsx')


average_education_salary = df.groupby('salary')['education-num'].mean()


print("Average education-num by salary group:")
print(average_education_salary)


plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='salary', y='education-num', palette="Set2")


plt.title("Education Level (education-num) by Salary")
plt.xlabel("Salary")
plt.ylabel("Education Level (education-num)")


plt.show()
# Out:
# Average education-num by salary group:
# salary
# <=50K     9.595065
# >50K     11.611657
# Name: education-num, dtype: float64
# C:\Users\anees\AppData\Local\Temp\ipykernel_16136\1144954202.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='salary', y='education-num', palette="Set2")

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df = pd.read_excel('dataset1.xlsx')


marital_salary_counts = pd.crosstab(df['marital-status'], df['salary'], normalize='index') * 100


print("Proportion of individuals earning >50K by marital status:")
print(marital_salary_counts['>50K'])


plt.figure(figsize=(10, 6))
marital_salary_counts['>50K'].sort_values().plot(kind='bar', color='skyblue')


plt.title("Proportion of Individuals Earning >50K by Marital Status")
plt.xlabel("Marital Status")
plt.ylabel("Percentage of Individuals Earning >50K")
plt.xticks(rotation=45)
plt.show()
# Out:
# Proportion of individuals earning >50K by marital status:
# marital-status
# Divorced                 10.420887
# Married-AF-spouse        43.478261
# Married-civ-spouse       44.684829
# Married-spouse-absent     8.133971
# Never-married             4.596087
# Separated                 6.439024
# Widowed                   8.559919
# Name: >50K, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df= pd.read_excel('dataset1.xlsx')


occupation_hours = df.groupby('occupation')['hours-per-week'].mean().sort_values()

plt.figure(figsize=(12, 8))
sns.barplot(x=occupation_hours.values, y=occupation_hours.index, palette="viridis")
plt.xlabel('Average Hours per Week')
plt.ylabel('Occupation')
plt.title('Average Hours per Week by Occupation')
plt.show()

top_occupations = occupation_hours.sort_values(ascending=False).head(5)
print("Occupations with the longest working hours:")
print(top_occupations)
# Out:
# C:\Users\anees\AppData\Local\Temp\ipykernel_29536\806335451.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=occupation_hours.values, y=occupation_hours.index, palette="viridis")
# Occupations with the longest working hours:
# occupation
# Farming-fishing     46.989940
# Exec-managerial     44.987703
# Transport-moving    44.656230
# Protective-serv     42.870570
# Prof-specialty      42.386715
# Name: hours-per-week, dtype: float64

# %%
import pandas as pd
from scipy.stats import ttest_ind

df= pd.read_excel('dataset1.xlsx')

male_hours = data[data['gender'] == 'Male']['hours-per-week']
female_hours = data[data['gender'] == 'Female']['hours-per-week']


t_stat, p_value = ttest_ind(male_hours, female_hours, equal_var=False)


print(f"T-statistic: {t_stat}")
print(f"P-value: {p_value}")


if p_value < 0.05:
    print("There is a significant difference in hours-per-week between males and females.")
else:
    print("There is no significant difference in hours-per-week between males and females.")

# %%
import pandas as pd
import matplotlib.pyplot as plt

df= pd.read_excel('dataset1.xlsx')
workclass_counts = df['workclass'].value_counts()


plt.figure(figsize=(10, 6))
workclass_counts.plot(kind='bar', color='skyblue')
plt.title('Number of Individuals in Each Workclass Category')
plt.xlabel('Workclass')
plt.ylabel('Number of Individuals')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()


highest_workclass = workclass_counts.idxmax()
highest_count = workclass_counts.max()

print(f"The workclass with the highest representation is '{highest_workclass}' with {highest_count} individuals.")
# Out:
# The workclass with the highest representation is 'Private' with 22696 individuals.
